# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nudeform.model import *
from nudeform.view import *

# %%
A = 72
beta = 0.4
gamma = np.pi/3
granularity = 360

# %%
phi, theta = np.mgrid[0:2*np.pi:(granularity)*1j, 0:np.pi:(granularity)*1j]

# %%
Rquadr = quadrupole_shape_scipy(phi,theta, beta = beta, gamma = gamma)
r0 = initial_radius(72)
R = r0*(1+Rquadr)
x,y,z = xyz(R,theta,phi)

# %%
shape_plot_3D(x, y, z, R, save = False, dpi=300, string = '', axis = False)
plt.show()

# %%
r_initial = initial_radius(A) * np.ones((360,360))
plot_radius_polar_coordinates(R, r_initial,phi, theta, save = False, dpi=300, string = '')

# %%
len(np.arange(0, np.pi*2, np.pi/6, dtype=float)),np.arange(0, np.pi*2, np.pi/6, dtype='g'),np.pi/6,np.pi*2
# Out:
# (12,
#  array([0.        , 0.52359878, 1.04719755, 1.57079633, 2.0943951 ,
#         2.61799388, 3.14159265, 3.66519143, 4.1887902 , 4.71238898,
#         5.23598776, 5.75958653], dtype=float128),
#  0.5235987755982988,
#  6.283185307179586)

# %%
beta = 0.4
for gamma in np.arange(0, np.pi*2, np.pi/6, dtype='g'):
    Rquadr = quadrupole_shape_scipy(phi,theta, beta = beta, gamma = gamma)
    r0 = initial_radius(72)
    R = r0*(1+Rquadr)
    string=f'beta={beta}_gamma={gamma}_A={A}'

    x,y,z = xyz(R,theta,phi)
    shape_plot_3D(x, y, z, R, save = False, dpi=300, string = string, axis = False)
    plt.show()
    plot_radius_polar_coordinates(R, r_initial,phi, theta, save = True, dpi=500, string = string)

# %%
np.where(R==np.min(R))
# Out:
# (array([ 90,  90, 269, 269]), array([179, 180, 179, 180]))

# %%
R[:,180],R[:,179]
# Out:
# (array([5.62200043, 5.62142175, 5.6196864 , 5.61679653, 5.61275566,
#         5.60756875, 5.60124215, 5.59378361, 5.58520228, 5.57550866,
#         5.56471463, 5.55283342, 5.53987957, 5.52586897, 5.51081878,
#         5.49474743, 5.47767461, 5.45962125, 5.44060946, 5.42066252,
#         5.39980489, 5.37806211, 5.35546082, 5.33202871, 5.30779449,
#         5.28278785, 5.25703942, 5.23058075, 5.20344427, 5.1756632 ,
#         5.14727159, 5.11830422, 5.08879659, 5.05878483, 5.02830573,
#         4.99739662, 4.96609537, 4.93444033, 4.90247028, 4.87022439,
#         4.83774216, 4.80506339, 4.77222812, 4.73927657, 4.70624911,
#         4.67318622, 4.64012838, 4.60711611, 4.57418985, 4.54138994,
#         4.50875656, 4.4763297 , 4.44414908, 4.41225412, 4.38068391,
#         4.34947711, 4.31867198, 4.28830623, 4.25841708, 4.22904115,
#         4.20021442, 4.17197222, 4.14434914, 4.11737902, 4.09109491,
#         4.065529  , 4.04071263, 4.01667619, 3.99344913, 3.97105992,
# ...

# %%
#R[ phi,theta}. phi [0,2pi,360] theta [0,pi,360]
plt.plot(R[:,180])
plt.show()
